# %% [markdown]
# # นาย จิตติณณ์ จินดานรเศรษฐ์ 6110405949

# %%
import pandas as pd
import datetime as dt
import numpy as np

# %% [markdown]
# ## 1.

# %%
italy_eq = pd.read_csv('italy_earthquakes_from_2016-08-24_to_2016-11-30.csv')

# %%
italy_eq
# Out:
#                          Time  Latitude  Longitude  Depth/Km  Magnitude
# 0     2016-08-24 03:36:32.000   42.6983    13.2335       8.1        6.0
# 1     2016-08-24 03:37:26.580   42.7123    13.2533       9.0        4.5
# 2     2016-08-24 03:40:46.590   42.7647    13.1723       9.7        3.8
# 3     2016-08-24 03:41:38.900   42.7803    13.1683       9.7        3.9
# 4     2016-08-24 03:42:07.170   42.7798    13.1575       9.7        3.6
# ...                       ...       ...        ...       ...        ...
# 8081  2016-11-30 18:39:27.600   42.8903    13.0197      10.7        2.0
# 8082  2016-11-30 18:43:14.850   42.9443    13.2003       8.6        2.6
# 8083  2016-11-30 20:18:27.550   43.0092    13.1288       8.0        2.2
# 8084  2016-11-30 20:45:11.780   43.0197    13.1017       9.3        2.7
# 8085  2016-11-30 20:54:35.890   42.9935    13.0753       9.5        2.3
#
# [8086 rows x 5 columns]

# %%
italy_eq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8086 entries, 0 to 8085
# Data columns (total 5 columns):
# Time         8086 non-null object
# Latitude     8086 non-null float64
# Longitude    8086 non-null float64
# Depth/Km     8086 non-null float64
# Magnitude    8086 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 316.0+ KB

# %% [markdown]
# ## 2.

# %%
italy_eq.Time
# Out:
# 0       2016-08-24 03:36:32.000
# 1       2016-08-24 03:37:26.580
# 2       2016-08-24 03:40:46.590
# 3       2016-08-24 03:41:38.900
# 4       2016-08-24 03:42:07.170
#                  ...
# 8081    2016-11-30 18:39:27.600
# 8082    2016-11-30 18:43:14.850
# 8083    2016-11-30 20:18:27.550
# 8084    2016-11-30 20:45:11.780
# 8085    2016-11-30 20:54:35.890
# Name: Time, Length: 8086, dtype: object

# %%
pd.to_datetime(italy_eq.Time)
# Out:
# 0      2016-08-24 03:36:32.000
# 1      2016-08-24 03:37:26.580
# 2      2016-08-24 03:40:46.590
# 3      2016-08-24 03:41:38.900
# 4      2016-08-24 03:42:07.170
#                  ...
# 8081   2016-11-30 18:39:27.600
# 8082   2016-11-30 18:43:14.850
# 8083   2016-11-30 20:18:27.550
# 8084   2016-11-30 20:45:11.780
# 8085   2016-11-30 20:54:35.890
# Name: Time, Length: 8086, dtype: datetime64[ns]

# %%
italy_eq.Time = pd.to_datetime(italy_eq.Time)

# %%
italy_eq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8086 entries, 0 to 8085
# Data columns (total 5 columns):
# Time         8086 non-null datetime64[ns]
# Latitude     8086 non-null float64
# Longitude    8086 non-null float64
# Depth/Km     8086 non-null float64
# Magnitude    8086 non-null float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 316.0 KB

# %%
italy_eq = italy_eq.set_index("Time")

# %%
italy_eq
# Out:
#                          Latitude  Longitude  Depth/Km  Magnitude
# Time
# 2016-08-24 03:36:32.000   42.6983    13.2335       8.1        6.0
# 2016-08-24 03:37:26.580   42.7123    13.2533       9.0        4.5
# 2016-08-24 03:40:46.590   42.7647    13.1723       9.7        3.8
# 2016-08-24 03:41:38.900   42.7803    13.1683       9.7        3.9
# 2016-08-24 03:42:07.170   42.7798    13.1575       9.7        3.6
# ...                           ...        ...       ...        ...
# 2016-11-30 18:39:27.600   42.8903    13.0197      10.7        2.0
# 2016-11-30 18:43:14.850   42.9443    13.2003       8.6        2.6
# 2016-11-30 20:18:27.550   43.0092    13.1288       8.0        2.2
# 2016-11-30 20:45:11.780   43.0197    13.1017       9.3        2.7
# 2016-11-30 20:54:35.890   42.9935    13.0753       9.5        2.3
#
# [8086 rows x 4 columns]

# %% [markdown]
# ## 3.

# %%
italy_eq[italy_eq.Magnitude == italy_eq.Magnitude.max()]
# Out:
#                          Latitude  Longitude  Depth/Km  Magnitude
# Time
# 2016-10-30 08:40:17.360   42.8322    13.1107       9.2        6.5

# %% [markdown]
# ## 4.

# %%
italy_eq.Magnitude.idxmax()
# Out:
# Timestamp('2016-10-30 08:40:17.360000')

# %%
italy_eq.Magnitude.idxmax().strftime('%Y-%m-%d')
# Out:
# '2016-10-30'

# %%
italy_eq[italy_eq.Magnitude.idxmax().strftime('%Y-%m-%d')].shape[0]
# Out:
# 389

# %% [markdown]
# ## 5.

# %%
t = italy_eq.Magnitude.idxmax().strftime('%Y-%m-%d')

# %%
italy_eq[t+' 07:00:00' : t+' 09:00:00']
# Out:
#                          Latitude  Longitude  Depth/Km  Magnitude
# Time
# 2016-10-30 07:01:14.060   42.8522    13.2443       8.9        2.4
# 2016-10-30 07:02:48.160   42.8538    13.2342       8.3        2.5
# 2016-10-30 07:14:48.470   42.8737    13.1502       9.2        2.4
# 2016-10-30 07:31:51.660   42.8753    13.0563       9.9        2.2
# 2016-10-30 08:04:07.760   42.7907    13.0872      10.2        2.4
# 2016-10-30 08:16:28.780   43.0622    13.0683       8.7        2.1
# 2016-10-30 08:31:19.890   42.9268    13.0287      10.8        2.0
# 2016-10-30 08:40:17.360   42.8322    13.1107       9.2        6.5
# 2016-10-30 08:41:17.010   42.7720    13.1358       9.3        4.3
# 2016-10-30 08:42:27.470   42.8795    13.0562       9.6        3.9
# 2016-10-30 08:43:08.810   42.7668    13.1383       9.7        4.0
# 2016-10-30 08:43:46.260   42.9000    13.1455       6.7        3.5
# 2016-10-30 08:44:30.670   42.8548    13.0853       8.3        4.6
# ...

# %% [markdown]
# ## 6.

# %%
t6 = italy_eq.sort_values('Magnitude', ascending=False)

# %%
t6
# Out:
#                          Latitude  Longitude  Depth/Km  Magnitude
# Time
# 2016-10-30 08:40:17.360   42.8322    13.1107       9.2        6.5
# 2016-08-24 03:36:32.000   42.6983    13.2335       8.1        6.0
# 2016-10-26 21:18:05.850   42.9087    13.1288       7.5        5.9
# 2016-08-24 04:33:28.890   42.7922    13.1507       8.0        5.4
# 2016-10-26 19:10:36.340   42.8802    13.1275       8.7        5.4
# ...                           ...        ...       ...        ...
# 2016-11-14 04:06:21.190   42.9403    13.2192       8.0        2.0
# 2016-08-25 13:36:47.650   42.5837    13.2723      10.8        2.0
# 2016-10-27 19:34:27.250   42.8753    13.0668      10.3        2.0
# 2016-10-27 19:35:20.480   42.9583    13.1428       9.3        2.0
# 2016-11-05 21:27:32.650   42.7957    13.0928      10.8        2.0
#
# [8086 rows x 4 columns]

# %%
t6[0:1]
# Out:
#                          Latitude  Longitude  Depth/Km  Magnitude
# Time
# 2016-10-30 08:40:17.360   42.8322    13.1107       9.2        6.5

# %%
t6[0:1].index
# Out:
# DatetimeIndex(['2016-10-30 08:40:17.360000'], dtype='datetime64[ns]', name='Time', freq=None)

# %%
t6[1:2]
# Out:
#                      Latitude  Longitude  Depth/Km  Magnitude
# Time
# 2016-08-24 03:36:32   42.6983    13.2335       8.1        6.0

# %%
t6[1:2].index
# Out:
# DatetimeIndex(['2016-08-24 03:36:32'], dtype='datetime64[ns]', name='Time', freq=None)

# %%
t6[0:1].index - t6[1:2].index
# Out:
# TimedeltaIndex(['67 days 05:03:45.360000'], dtype='timedelta64[ns]', name='Time', freq=None)

# %% [markdown]
# ## 7.

# %%
t5 = italy_eq[t+' 07:00:00' : t+' 09:00:00']

# %%
t5
# Out:
#                          Latitude  Longitude  Depth/Km  Magnitude
# Time
# 2016-10-30 07:01:14.060   42.8522    13.2443       8.9        2.4
# 2016-10-30 07:02:48.160   42.8538    13.2342       8.3        2.5
# 2016-10-30 07:14:48.470   42.8737    13.1502       9.2        2.4
# 2016-10-30 07:31:51.660   42.8753    13.0563       9.9        2.2
# 2016-10-30 08:04:07.760   42.7907    13.0872      10.2        2.4
# 2016-10-30 08:16:28.780   43.0622    13.0683       8.7        2.1
# 2016-10-30 08:31:19.890   42.9268    13.0287      10.8        2.0
# 2016-10-30 08:40:17.360   42.8322    13.1107       9.2        6.5
# 2016-10-30 08:41:17.010   42.7720    13.1358       9.3        4.3
# 2016-10-30 08:42:27.470   42.8795    13.0562       9.6        3.9
# 2016-10-30 08:43:08.810   42.7668    13.1383       9.7        4.0
# 2016-10-30 08:43:46.260   42.9000    13.1455       6.7        3.5
# 2016-10-30 08:44:30.670   42.8548    13.0853       8.3        4.6
# ...

# %%
t5.diff()
# Out:
#                          Latitude  Longitude  Depth/Km  Magnitude
# Time
# 2016-10-30 07:01:14.060       NaN        NaN       NaN        NaN
# 2016-10-30 07:02:48.160    0.0016    -0.0101      -0.6        0.1
# 2016-10-30 07:14:48.470    0.0199    -0.0840       0.9       -0.1
# 2016-10-30 07:31:51.660    0.0016    -0.0939       0.7       -0.2
# 2016-10-30 08:04:07.760   -0.0846     0.0309       0.3        0.2
# 2016-10-30 08:16:28.780    0.2715    -0.0189      -1.5       -0.3
# 2016-10-30 08:31:19.890   -0.1354    -0.0396       2.1       -0.1
# 2016-10-30 08:40:17.360   -0.0946     0.0820      -1.6        4.5
# 2016-10-30 08:41:17.010   -0.0602     0.0251       0.1       -2.2
# 2016-10-30 08:42:27.470    0.1075    -0.0796       0.3       -0.4
# 2016-10-30 08:43:08.810   -0.1127     0.0821       0.1        0.1
# 2016-10-30 08:43:46.260    0.1332     0.0072      -3.0       -0.5
# 2016-10-30 08:44:30.670   -0.0452    -0.0602       1.6        1.1
# ...

# %% [markdown]
# ## 8.

# %%
t8 = italy_eq

# %%
t8 = t8.assign(Count=1)

# %%
t8.resample('1d').sum()
# Out:
#               Latitude  Longitude  Depth/Km  Magnitude  Count
# Time
# 2016-08-24  21710.0373  6708.5980    4806.3     1352.1    508
# 2016-08-25  10254.2648  3173.6875    2329.0      559.9    240
# 2016-08-26   9055.4136  2805.1993    1954.8      501.1    212
# 2016-08-27   5982.8914  1853.1319    1334.2      330.2    140
# 2016-08-28   4699.4089  1453.5420    1087.9      257.5    110
# ...                ...        ...       ...        ...    ...
# 2016-11-26   1757.7057   538.1176     454.5       93.9     41
# 2016-11-27   3135.2517   957.0202     677.9      178.8     73
# 2016-11-28   3522.4596  1074.1951     787.0      188.2     82
# 2016-11-29   3986.5639  1222.3662     924.4      215.8     93
# 2016-11-30   2013.1899   618.9234     493.6      106.7     47
#
# [99 rows x 5 columns]

# %% [markdown]
# ## 9.

# %%
t8.resample('1h').sum()
# Out:
#                       Latitude  Longitude  Depth/Km  Magnitude  Count
# Time
# 2016-08-24 03:00:00   811.9491   250.9745     185.6       65.9     19
# 2016-08-24 04:00:00  2606.2257   805.8693     574.4      187.5     61
# 2016-08-24 05:00:00  3076.6592   950.4156     662.9      194.6     72
# 2016-08-24 06:00:00  2349.8418   725.9646     508.3      148.0     55
# 2016-08-24 07:00:00  2307.6176   713.2353     533.6      131.9     54
# ...                        ...        ...       ...        ...    ...
# 2016-11-30 16:00:00    85.5816    26.4073      21.1        5.5      2
# 2016-11-30 17:00:00   128.6222    39.3105      28.5        6.7      3
# 2016-11-30 18:00:00   128.7801    39.4278      26.1        6.9      3
# 2016-11-30 19:00:00     0.0000     0.0000       0.0        0.0      0
# 2016-11-30 20:00:00   129.0224    39.3058      26.8        7.2      3
#
# [2370 rows x 5 columns]

# %%
t8.resample('1h').sum().Count == 0
# Out:
# Time
# 2016-08-24 03:00:00    False
# 2016-08-24 04:00:00    False
# 2016-08-24 05:00:00    False
# 2016-08-24 06:00:00    False
# 2016-08-24 07:00:00    False
#                        ...
# 2016-11-30 16:00:00    False
# 2016-11-30 17:00:00    False
# 2016-11-30 18:00:00    False
# 2016-11-30 19:00:00     True
# 2016-11-30 20:00:00    False
# Freq: H, Name: Count, Length: 2370, dtype: bool

# %%
(t8.resample('1h').sum().Count == 0).value_counts()
# Out:
# False    1611
# True      759
# Name: Count, dtype: int64

# %%
(t8.resample('1h').sum().Count == 0).sum()
# Out:
# 759

# %% [markdown]
# ## 10.

# %%
t10 = t8.resample('5t').mean()

# %%
t10
# Out:
#                       Latitude  Longitude  Depth/Km  Magnitude  Count
# Time
# 2016-08-24 03:35:00  42.705300  13.243400      8.55   5.250000    1.0
# 2016-08-24 03:40:00  42.726467  13.210400     10.20   3.433333    1.0
# 2016-08-24 03:45:00  42.725500  13.237067      8.50   3.266667    1.0
# 2016-08-24 03:50:00  42.691250  13.257000      9.40   3.000000    1.0
# 2016-08-24 03:55:00  42.770117  13.166683     10.50   3.166667    1.0
# ...                        ...        ...       ...        ...    ...
# 2016-11-30 20:30:00        NaN        NaN       NaN        NaN    NaN
# 2016-11-30 20:35:00        NaN        NaN       NaN        NaN    NaN
# 2016-11-30 20:40:00        NaN        NaN       NaN        NaN    NaN
# 2016-11-30 20:45:00  43.019700  13.101700      9.30   2.700000    1.0
# 2016-11-30 20:50:00  42.993500  13.075300      9.50   2.300000    1.0
#
# [28432 rows x 5 columns]

# %%
t10.Magnitude.max()
# Out:
# 5.4

# %%
t10[t10.Magnitude == t10.Magnitude.max()]
# Out:
#                      Latitude  Longitude  Depth/Km  Magnitude  Count
# Time
# 2016-10-26 19:10:00   42.8802    13.1275       8.7        5.4    1.0

# %% [markdown]
# ## 11.

# %%
italy_eq.index.to_series().diff()
# Out:
# Time
# 2016-08-24 03:36:32.000               NaT
# 2016-08-24 03:37:26.580   00:00:54.580000
# 2016-08-24 03:40:46.590   00:03:20.010000
# 2016-08-24 03:41:38.900   00:00:52.310000
# 2016-08-24 03:42:07.170   00:00:28.270000
#                                 ...
# 2016-11-30 18:39:27.600   00:30:10.680000
# 2016-11-30 18:43:14.850   00:03:47.250000
# 2016-11-30 20:18:27.550   01:35:12.700000
# 2016-11-30 20:45:11.780   00:26:44.230000
# 2016-11-30 20:54:35.890   00:09:24.110000
# Name: Time, Length: 8086, dtype: timedelta64[ns]

# %%
italy_eq.index.to_series().diff().to_frame()
# Out:
#                                    Time
# Time
# 2016-08-24 03:36:32.000             NaT
# 2016-08-24 03:37:26.580 00:00:54.580000
# 2016-08-24 03:40:46.590 00:03:20.010000
# 2016-08-24 03:41:38.900 00:00:52.310000
# 2016-08-24 03:42:07.170 00:00:28.270000
# ...                                 ...
# 2016-11-30 18:39:27.600 00:30:10.680000
# 2016-11-30 18:43:14.850 00:03:47.250000
# 2016-11-30 20:18:27.550 01:35:12.700000
# 2016-11-30 20:45:11.780 00:26:44.230000
# 2016-11-30 20:54:35.890 00:09:24.110000
#
# [8086 rows x 1 columns]

# %%
italy_eq.index.to_series().diff().max()
# Out:
# Timedelta('0 days 16:46:16.250000')

# %% [markdown]
# ## 12.

# %%
italy_eq.index.to_frame().shift(1)
# Out:
#                                            Time
# Time
# 2016-08-24 03:36:32.000                     NaT
# 2016-08-24 03:37:26.580 2016-08-24 03:36:32.000
# 2016-08-24 03:40:46.590 2016-08-24 03:37:26.580
# 2016-08-24 03:41:38.900 2016-08-24 03:40:46.590
# 2016-08-24 03:42:07.170 2016-08-24 03:41:38.900
# ...                                         ...
# 2016-11-30 18:39:27.600 2016-11-30 18:09:16.920
# 2016-11-30 18:43:14.850 2016-11-30 18:39:27.600
# 2016-11-30 20:18:27.550 2016-11-30 18:43:14.850
# 2016-11-30 20:45:11.780 2016-11-30 20:18:27.550
# 2016-11-30 20:54:35.890 2016-11-30 20:45:11.780
#
# [8086 rows x 1 columns]

# %%
df12 = italy_eq.index.to_frame().shift(1)

# %%
df12.columns = ['Previous']

# %%
df12['Duration'] = df12.index.to_series().diff()

# %%
df12
# Out:
#                                        Previous        Duration
# Time
# 2016-08-24 03:36:32.000                     NaT             NaT
# 2016-08-24 03:37:26.580 2016-08-24 03:36:32.000 00:00:54.580000
# 2016-08-24 03:40:46.590 2016-08-24 03:37:26.580 00:03:20.010000
# 2016-08-24 03:41:38.900 2016-08-24 03:40:46.590 00:00:52.310000
# 2016-08-24 03:42:07.170 2016-08-24 03:41:38.900 00:00:28.270000
# ...                                         ...             ...
# 2016-11-30 18:39:27.600 2016-11-30 18:09:16.920 00:30:10.680000
# 2016-11-30 18:43:14.850 2016-11-30 18:39:27.600 00:03:47.250000
# 2016-11-30 20:18:27.550 2016-11-30 18:43:14.850 01:35:12.700000
# 2016-11-30 20:45:11.780 2016-11-30 20:18:27.550 00:26:44.230000
# 2016-11-30 20:54:35.890 2016-11-30 20:45:11.780 00:09:24.110000
#
# [8086 rows x 2 columns]

# %%
df12.Duration.idxmax()
# Out:
# Timestamp('2016-10-25 20:00:10.480000')

# %%
df12.loc[[df12.Duration.idxmax()]]
# Out:
#                                        Previous        Duration
# Time
# 2016-10-25 20:00:10.480 2016-10-25 03:13:54.230 16:46:16.250000

# %% [markdown]
# ## 13.

# %%
italy_eq
# Out:
#                          Latitude  Longitude  Depth/Km  Magnitude
# Time
# 2016-08-24 03:36:32.000   42.6983    13.2335       8.1        6.0
# 2016-08-24 03:37:26.580   42.7123    13.2533       9.0        4.5
# 2016-08-24 03:40:46.590   42.7647    13.1723       9.7        3.8
# 2016-08-24 03:41:38.900   42.7803    13.1683       9.7        3.9
# 2016-08-24 03:42:07.170   42.7798    13.1575       9.7        3.6
# ...                           ...        ...       ...        ...
# 2016-11-30 18:39:27.600   42.8903    13.0197      10.7        2.0
# 2016-11-30 18:43:14.850   42.9443    13.2003       8.6        2.6
# 2016-11-30 20:18:27.550   43.0092    13.1288       8.0        2.2
# 2016-11-30 20:45:11.780   43.0197    13.1017       9.3        2.7
# 2016-11-30 20:54:35.890   42.9935    13.0753       9.5        2.3
#
# [8086 rows x 4 columns]

# %%
pd.concat([italy_eq.Magnitude, italy_eq.Magnitude.shift(1), italy_eq.Magnitude.shift(-1)], axis=1)
# Out:
#                          Magnitude  Magnitude  Magnitude
# Time
# 2016-08-24 03:36:32.000        6.0        NaN        4.5
# 2016-08-24 03:37:26.580        4.5        6.0        3.8
# 2016-08-24 03:40:46.590        3.8        4.5        3.9
# 2016-08-24 03:41:38.900        3.9        3.8        3.6
# 2016-08-24 03:42:07.170        3.6        3.9        3.4
# ...                            ...        ...        ...
# 2016-11-30 18:39:27.600        2.0        2.3        2.6
# 2016-11-30 18:43:14.850        2.6        2.0        2.2
# 2016-11-30 20:18:27.550        2.2        2.6        2.7
# 2016-11-30 20:45:11.780        2.7        2.2        2.3
# 2016-11-30 20:54:35.890        2.3        2.7        NaN
#
# [8086 rows x 3 columns]

# %%
dfc13 = pd.concat([italy_eq.Magnitude, italy_eq.Magnitude.shift(1), italy_eq.Magnitude.shift(-1)], axis=1)

# %%
dfc13.columns = ['Magnitude', 'Previous', 'Next']

# %%
dfc13
# Out:
#                          Magnitude  Previous  Next
# Time
# 2016-08-24 03:36:32.000        6.0       NaN   4.5
# 2016-08-24 03:37:26.580        4.5       6.0   3.8
# 2016-08-24 03:40:46.590        3.8       4.5   3.9
# 2016-08-24 03:41:38.900        3.9       3.8   3.6
# 2016-08-24 03:42:07.170        3.6       3.9   3.4
# ...                            ...       ...   ...
# 2016-11-30 18:39:27.600        2.0       2.3   2.6
# 2016-11-30 18:43:14.850        2.6       2.0   2.2
# 2016-11-30 20:18:27.550        2.2       2.6   2.7
# 2016-11-30 20:45:11.780        2.7       2.2   2.3
# 2016-11-30 20:54:35.890        2.3       2.7   NaN
#
# [8086 rows x 3 columns]

# %%
dfc13['Diff_Previous'] = dfc13.Magnitude - dfc13.Previous

# %%
dfc13['Diff_Next'] = dfc13.Magnitude - dfc13.Next

# %%
dfc13
# Out:
#                          Magnitude  Previous  Next  Diff_Previous  Diff_Next
# Time
# 2016-08-24 03:36:32.000        6.0       NaN   4.5            NaN        1.5
# 2016-08-24 03:37:26.580        4.5       6.0   3.8           -1.5        0.7
# 2016-08-24 03:40:46.590        3.8       4.5   3.9           -0.7       -0.1
# 2016-08-24 03:41:38.900        3.9       3.8   3.6            0.1        0.3
# 2016-08-24 03:42:07.170        3.6       3.9   3.4           -0.3        0.2
# ...                            ...       ...   ...            ...        ...
# 2016-11-30 18:39:27.600        2.0       2.3   2.6           -0.3       -0.6
# 2016-11-30 18:43:14.850        2.6       2.0   2.2            0.6        0.4
# 2016-11-30 20:18:27.550        2.2       2.6   2.7           -0.4       -0.5
# 2016-11-30 20:45:11.780        2.7       2.2   2.3            0.5        0.4
# 2016-11-30 20:54:35.890        2.3       2.7   NaN           -0.4        NaN
#
# [8086 rows x 5 columns]

# %%
dfc13.loc[(dfc13.Diff_Previous >= 2) & (dfc13.Diff_Next >= 2)]
# Out:
#                          Magnitude  Previous  Next  Diff_Previous  Diff_Next
# Time
# 2016-08-24 04:33:28.890        5.4       2.5   2.8            2.9        2.6
# 2016-10-26 19:10:36.340        5.4       2.1   2.6            3.3        2.8
# 2016-10-26 21:18:05.850        5.9       2.2   3.6            3.7        2.3
# 2016-10-30 08:40:17.360        6.5       2.0   4.3            4.5        2.2
# 2016-11-29 18:14:02.690        4.4       2.4   2.4            2.0        2.0

# %%
b13 = (italy_eq.Magnitude - italy_eq.Magnitude.shift(1) >= 2) & (italy_eq.Magnitude - italy_eq.Magnitude.shift(-1) >= 2)

# %%
italy_eq.loc[b13]
# Out:
#                          Latitude  Longitude  Depth/Km  Magnitude
# Time
# 2016-08-24 04:33:28.890   42.7922    13.1507       8.0        5.4
# 2016-10-26 19:10:36.340   42.8802    13.1275       8.7        5.4
# 2016-10-26 21:18:05.850   42.9087    13.1288       7.5        5.9
# 2016-10-30 08:40:17.360   42.8322    13.1107       9.2        6.5
# 2016-11-29 18:14:02.690   42.5293    13.2803      11.1        4.4

# %% [markdown]
# ## 14.

# %%
df14 = italy_eq.copy()

# %%
df14['Date_Hour'] = df14.index.strftime('%Y-%m-%d %H')

# %%
df14
# Out:
#                          Latitude  Longitude  Depth/Km  Magnitude  \
# Time
# 2016-08-24 03:36:32.000   42.6983    13.2335       8.1        6.0
# 2016-08-24 03:37:26.580   42.7123    13.2533       9.0        4.5
# 2016-08-24 03:40:46.590   42.7647    13.1723       9.7        3.8
# 2016-08-24 03:41:38.900   42.7803    13.1683       9.7        3.9
# 2016-08-24 03:42:07.170   42.7798    13.1575       9.7        3.6
# ...                           ...        ...       ...        ...
# 2016-11-30 18:39:27.600   42.8903    13.0197      10.7        2.0
# 2016-11-30 18:43:14.850   42.9443    13.2003       8.6        2.6
# 2016-11-30 20:18:27.550   43.0092    13.1288       8.0        2.2
# 2016-11-30 20:45:11.780   43.0197    13.1017       9.3        2.7
# 2016-11-30 20:54:35.890   42.9935    13.0753       9.5        2.3
#
#                              Date_Hour
# Time
# 2016-08-24 03:36:32.000  2016-08-24 03
# 2016-08-24 03:37:26.580  2016-08-24 03
# 2016-08-24 03:40:46.590  2016-08-24 03
# ...

# %%
df14.index.strftime('%Y-%m-%d %H').to_frame()
# Out:
#                            0
# 2016-08-24 03  2016-08-24 03
# 2016-08-24 03  2016-08-24 03
# 2016-08-24 03  2016-08-24 03
# 2016-08-24 03  2016-08-24 03
# 2016-08-24 03  2016-08-24 03
# ...                      ...
# 2016-11-30 18  2016-11-30 18
# 2016-11-30 18  2016-11-30 18
# 2016-11-30 20  2016-11-30 20
# 2016-11-30 20  2016-11-30 20
# 2016-11-30 20  2016-11-30 20
#
# [8086 rows x 1 columns]

# %%
df14.index.strftime('%Y-%m-%d %H').value_counts().to_frame()
# Out:
#                 0
# 2016-08-24 05  72
# 2016-08-24 04  61
# 2016-08-24 06  55
# 2016-08-24 07  54
# 2016-10-30 09  48
# ...            ..
# 2016-09-02 19   1
# 2016-10-19 19   1
# 2016-09-19 23   1
# 2016-09-11 11   1
# 2016-09-12 08   1
#
# [1611 rows x 1 columns]

# %%
df14 = df14.reset_index().join(df14.index.strftime('%Y-%m-%d %H').value_counts().to_frame(), on='Date_Hour')

# %%
df14
# Out:
#                         Time  Latitude  Longitude  Depth/Km  Magnitude  \
# 0    2016-08-24 03:36:32.000   42.6983    13.2335       8.1        6.0
# 1    2016-08-24 03:37:26.580   42.7123    13.2533       9.0        4.5
# 2    2016-08-24 03:40:46.590   42.7647    13.1723       9.7        3.8
# 3    2016-08-24 03:41:38.900   42.7803    13.1683       9.7        3.9
# 4    2016-08-24 03:42:07.170   42.7798    13.1575       9.7        3.6
# ...                      ...       ...        ...       ...        ...
# 8081 2016-11-30 18:39:27.600   42.8903    13.0197      10.7        2.0
# 8082 2016-11-30 18:43:14.850   42.9443    13.2003       8.6        2.6
# 8083 2016-11-30 20:18:27.550   43.0092    13.1288       8.0        2.2
# 8084 2016-11-30 20:45:11.780   43.0197    13.1017       9.3        2.7
# 8085 2016-11-30 20:54:35.890   42.9935    13.0753       9.5        2.3
#
#           Date_Hour   0
# 0     2016-08-24 03  19
# 1     2016-08-24 03  19
# 2     2016-08-24 03  19
# ...

# %%
df14.columns = ['Time', 'Latitude', 'Longitude', 'Depth/Km', 'Magnitude', 'Date_Hour',
       'hour_count']

# %%
df14
# Out:
#                         Time  Latitude  Longitude  Depth/Km  Magnitude  \
# 0    2016-08-24 03:36:32.000   42.6983    13.2335       8.1        6.0
# 1    2016-08-24 03:37:26.580   42.7123    13.2533       9.0        4.5
# 2    2016-08-24 03:40:46.590   42.7647    13.1723       9.7        3.8
# 3    2016-08-24 03:41:38.900   42.7803    13.1683       9.7        3.9
# 4    2016-08-24 03:42:07.170   42.7798    13.1575       9.7        3.6
# ...                      ...       ...        ...       ...        ...
# 8081 2016-11-30 18:39:27.600   42.8903    13.0197      10.7        2.0
# 8082 2016-11-30 18:43:14.850   42.9443    13.2003       8.6        2.6
# 8083 2016-11-30 20:18:27.550   43.0092    13.1288       8.0        2.2
# 8084 2016-11-30 20:45:11.780   43.0197    13.1017       9.3        2.7
# 8085 2016-11-30 20:54:35.890   42.9935    13.0753       9.5        2.3
#
#           Date_Hour  hour_count
# 0     2016-08-24 03          19
# 1     2016-08-24 03          19
# ...

# %%
df14 = df14.drop(columns='Date_Hour')

# %%
df14 = df14.set_index('Time')

# %%
df14.loc[b13]
# Out:
#                          Latitude  Longitude  Depth/Km  Magnitude  hour_count
# Time
# 2016-08-24 04:33:28.890   42.7922    13.1507       8.0        5.4          61
# 2016-10-26 19:10:36.340   42.8802    13.1275       8.7        5.4          12
# 2016-10-26 21:18:05.850   42.9087    13.1288       7.5        5.9          24
# 2016-10-30 08:40:17.360   42.8322    13.1107       9.2        6.5          26
# 2016-11-29 18:14:02.690   42.5293    13.2803      11.1        4.4          11

# %% [markdown]
# ## 15.

# %%
italy_eq.index.strftime('%H').to_frame()
# Out:
#      0
# 03  03
# 03  03
# 03  03
# 03  03
# 03  03
# ..  ..
# 18  18
# 18  18
# 20  20
# 20  20
# 20  20
#
# [8086 rows x 1 columns]

# %%
df15 = italy_eq.index.strftime('%H').value_counts().to_frame().sort_index()
df15.columns = ['Frequency']
df15
# Out:
#     Frequency
# 00        333
# 01        303
# 02        307
# 03        303
# 04        343
# 05        395
# 06        403
# 07        401
# 08        363
# 09        388
# 10        336
# 11        327
# 12        338
# 13        315
# 14        351
# 15        331
# 16        295
# 17        317
# 18        317
# 19        340
# 20        314
# 21        310
# 22        317
# 23        339
