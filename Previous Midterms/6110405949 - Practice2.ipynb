# %% [markdown]
# # นาย จิตติณณ์ จินดานรเศรษฐ์ 6110405949

# %%
import pandas as pd

# %% [markdown]
# ## 1.

# %%
medals = pd.read_csv('olympics.csv')

# %%
medals
# Out:
#                                        Unnamed: 0  № Summer  01 !  02 !  03 !  \
# 0                               Afghanistan (AFG)        13     0     0     2
# 1                                   Algeria (ALG)        12     5     2     8
# 2                                 Argentina (ARG)        23    18    24    28
# 3                                   Armenia (ARM)         5     1     2     9
# 4                         Australasia (ANZ) [ANZ]         2     3     4     5
# ..                                            ...       ...   ...   ...   ...
# 141                        Yugoslavia (YUG) [YUG]        16    26    29    28
# 142  Independent Olympic Participants (IOP) [IOP]         1     0     1     2
# 143                            Zambia (ZAM) [ZAM]        12     0     1     1
# 144                          Zimbabwe (ZIM) [ZIM]        12     3     4     1
# 145                        Mixed team (ZZX) [ZZX]         3     8     5     4
#
# ...

# %%
medals.columns
# Out:
# Index(['Unnamed: 0', '№ Summer', '01 !', '02 !', '03 !', '№ Winter', '01 !.1',
#        '02 !.1', '03 !.1'],
#       dtype='object')

# %%
medals.columns = ['Country_Full', 'No_Summer', 'S_Gold', 'S_Silver', 'S_Bronze', 'No_Winter', 'W_Gold',
       'W_Silver', 'W_Bronze']

# %%
medals
# Out:
#                                      Country_Full  No_Summer  S_Gold  \
# 0                               Afghanistan (AFG)         13       0
# 1                                   Algeria (ALG)         12       5
# 2                                 Argentina (ARG)         23      18
# 3                                   Armenia (ARM)          5       1
# 4                         Australasia (ANZ) [ANZ]          2       3
# ..                                            ...        ...     ...
# 141                        Yugoslavia (YUG) [YUG]         16      26
# 142  Independent Olympic Participants (IOP) [IOP]          1       0
# 143                            Zambia (ZAM) [ZAM]         12       0
# 144                          Zimbabwe (ZIM) [ZIM]         12       3
# 145                        Mixed team (ZZX) [ZZX]          3       8
#
#      S_Silver  S_Bronze  No_Winter  W_Gold  W_Silver  W_Bronze
# 0           0         2          0       0         0         0
# ...

# %% [markdown]
# ## 2.

# %%
drinks = pd.read_csv('drinks.csv')

# %%
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %% [markdown]
# ## 3.

# %%
drinks.isnull().sum()
# Out:
# country                          0
# beer_servings                    0
# spirit_servings                  0
# wine_servings                    0
# total_litres_of_pure_alcohol     0
# continent                       23
# dtype: int64

# %% [markdown]
# ## 4.

# %%
medals.Country_Full.str.extract("(.+)\s\(")
# Out:
#                                     0
# 0                         Afghanistan
# 1                             Algeria
# 2                           Argentina
# 3                             Armenia
# 4                         Australasia
# ..                                ...
# 141                        Yugoslavia
# 142  Independent Olympic Participants
# 143                            Zambia
# 144                          Zimbabwe
# 145                        Mixed team
#
# [146 rows x 1 columns]

# %%
medals['Country'] = medals.Country_Full.str.extract("(.+)\s\(")

# %%
medals
# Out:
#                                      Country_Full  No_Summer  S_Gold  \
# 0                               Afghanistan (AFG)         13       0
# 1                                   Algeria (ALG)         12       5
# 2                                 Argentina (ARG)         23      18
# 3                                   Armenia (ARM)          5       1
# 4                         Australasia (ANZ) [ANZ]          2       3
# ..                                            ...        ...     ...
# 141                        Yugoslavia (YUG) [YUG]         16      26
# 142  Independent Olympic Participants (IOP) [IOP]          1       0
# 143                            Zambia (ZAM) [ZAM]         12       0
# 144                          Zimbabwe (ZIM) [ZIM]         12       3
# 145                        Mixed team (ZZX) [ZZX]          3       8
#
#      S_Silver  S_Bronze  No_Winter  W_Gold  W_Silver  W_Bronze  \
# 0           0         2          0       0         0         0
# ...

# %%
b4 = medals.Country.isin(drinks.country)

# %%
medals.loc[~b4]
# Out:
#                                      Country_Full  No_Summer  S_Gold  \
# 4                         Australasia (ANZ) [ANZ]          2       3
# 13                                  Bermuda (BER)         17       0
# 14                        Bohemia (BOH) [BOH] [Z]          3       0
# 17                British West Indies (BWI) [BWI]          1       0
# 26                        Ivory Coast (CIV) [CIV]         12       0
# 31                     Czechoslovakia (TCH) [TCH]         16      49
# 45             United Team of Germany (EUA) [EUA]          3      28
# 46                       East Germany (GDR) [GDR]          5     153
# 47                       West Germany (FRG) [FRG]          5      56
# 49                  Great Britain (GBR) [GBR] [Z]         27     236
# 55                          Hong Kong (HKG) [HKG]         15       1
# 75                            Liechtenstein (LIE)         16       0
# 89           Netherlands Antilles (AHO) [AHO] [I]         13       0
# ...

# %% [markdown]
# ## 5.

# %%
b5 = drinks.country.isin(medals.Country)

# %%
drinks.loc[~b5]
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 1              Albania             89              132             54
# 3              Andorra            245              138            312
# 4               Angola            217               57             45
# 5    Antigua & Barbuda            102              128             45
# 13          Bangladesh              0                0              0
# ..                 ...            ...              ...            ...
# 178             Tuvalu              6               41              9
# 182     United Kingdom            219              126            195
# 184                USA            249              158             84
# 187            Vanuatu             21               18             11
# 190              Yemen              6                0              0
#
#      total_litres_of_pure_alcohol continent
# 1                             4.9        EU
# ...

# %% [markdown]
# ## 6.

# %%
medals = medals.set_index('Country')

# %%
drinks = drinks.set_index('country')

# %%
medals = medals.join(drinks.continent)

# %%
medals
# Out:
#                                                                   Country_Full  \
# Country
# Afghanistan                                                  Afghanistan (AFG)
# Algeria                                                          Algeria (ALG)
# Argentina                                                      Argentina (ARG)
# Armenia                                                          Armenia (ARM)
# Australasia                                            Australasia (ANZ) [ANZ]
# ...                                                                        ...
# Yugoslavia                                              Yugoslavia (YUG) [YUG]
# Independent Olympic Participants  Independent Olympic Participants (IOP) [IOP]
# Zambia                                                      Zambia (ZAM) [ZAM]
# Zimbabwe                                                  Zimbabwe (ZIM) [ZIM]
# Mixed team                                              Mixed team (ZZX) [ZZX]
#
# ...

# %% [markdown]
# ## 7.

# %%
medals[medals.continent.isnull()]
# Out:
#                                                                   Country_Full  \
# Country
# Australasia                                            Australasia (ANZ) [ANZ]
# Bahamas                                                          Bahamas (BAH)
# Barbados                                                  Barbados (BAR) [BAR]
# Bermuda                                                          Bermuda (BER)
# Bohemia                                                Bohemia (BOH) [BOH] [Z]
# British West Indies                            British West Indies (BWI) [BWI]
# Canada                                                            Canada (CAN)
# Costa Rica                                                    Costa Rica (CRC)
# Ivory Coast                                            Ivory Coast (CIV) [CIV]
# Cuba                                                            Cuba (CUB) [Z]
# Czechoslovakia                                      Czechoslovakia (TCH) [TCH]
# ...

# %% [markdown]
# ## 8.

# %%
medals.continent = medals.continent.fillna('OT')

# %%
medals
# Out:
#                                                                   Country_Full  \
# Country
# Afghanistan                                                  Afghanistan (AFG)
# Algeria                                                          Algeria (ALG)
# Argentina                                                      Argentina (ARG)
# Armenia                                                          Armenia (ARM)
# Australasia                                            Australasia (ANZ) [ANZ]
# ...                                                                        ...
# Yugoslavia                                              Yugoslavia (YUG) [YUG]
# Independent Olympic Participants  Independent Olympic Participants (IOP) [IOP]
# Zambia                                                      Zambia (ZAM) [ZAM]
# Zimbabwe                                                  Zimbabwe (ZIM) [ZIM]
# Mixed team                                              Mixed team (ZZX) [ZZX]
#
# ...

# %%
medals.loc[['Australasia'], 'continent'] = 'OC'

# %%
medals.loc[['Canada', 'United States', 'Mexico'], 'continent'] = 'NA'

# %%
medals.loc[['Cuba', 'Jamaica'], 'continent'] = 'SA'

# %%
medals.loc[['Czechoslovakia', 'Yugoslavia', 'Great Britain', 'Soviet Union', 'United Team of Germany', 'East Germany', 'West Germany', 'Russia', 'Russian Empire'], 'continent'] = 'EU'

# %%
medals
# Out:
#                                                                   Country_Full  \
# Country
# Afghanistan                                                  Afghanistan (AFG)
# Algeria                                                          Algeria (ALG)
# Argentina                                                      Argentina (ARG)
# Armenia                                                          Armenia (ARM)
# Australasia                                            Australasia (ANZ) [ANZ]
# ...                                                                        ...
# Yugoslavia                                              Yugoslavia (YUG) [YUG]
# Independent Olympic Participants  Independent Olympic Participants (IOP) [IOP]
# Zambia                                                      Zambia (ZAM) [ZAM]
# Zimbabwe                                                  Zimbabwe (ZIM) [ZIM]
# Mixed team                                              Mixed team (ZZX) [ZZX]
#
# ...

# %% [markdown]
# ## 9.

# %%
medals = medals.reset_index()

# %%
medals = medals.set_index(['continent', 'Country'])

# %%
medals
# Out:
#                                                                             Country_Full  \
# continent Country
# AS        Afghanistan                                                  Afghanistan (AFG)
# AF        Algeria                                                          Algeria (ALG)
# SA        Argentina                                                      Argentina (ARG)
# EU        Armenia                                                          Armenia (ARM)
# OC        Australasia                                            Australasia (ANZ) [ANZ]
# ...                                                                                  ...
# EU        Yugoslavia                                              Yugoslavia (YUG) [YUG]
# OT        Independent Olympic Participants  Independent Olympic Participants (IOP) [IOP]
# AF        Zambia                                                      Zambia (ZAM) [ZAM]
# ...

# %% [markdown]
# ## 10.

# %%
medals = medals.sort_index(level=['continent', 'Country'], ascending=[False, True])

# %%
medals
# Out:
#                              Country_Full  No_Summer  S_Gold  S_Silver  \
# continent Country
# SA        Argentina       Argentina (ARG)         23      18        24
#           Brazil             Brazil (BRA)         21      23        30
#           Chile           Chile (CHI) [I]         22       2         7
#           Colombia         Colombia (COL)         18       2         6
#           Cuba             Cuba (CUB) [Z]         19      72        67
# ...                                   ...        ...     ...       ...
# AF        Togo                 Togo (TOG)          9       0         0
#           Tunisia           Tunisia (TUN)         13       3         3
#           Uganda             Uganda (UGA)         14       2         3
#           Zambia       Zambia (ZAM) [ZAM]         12       0         1
#           Zimbabwe   Zimbabwe (ZIM) [ZIM]         12       3         4
#
#                      S_Bronze  No_Winter  W_Gold  W_Silver  W_Bronze
# continent Country
# ...

# %% [markdown]
# ## 11.

# %%
s_medals = medals.iloc[:,1:5]

# %%
s_medals.columns = ['Games','Gold','Silver','Bronze']

# %%
s_medals
# Out:
#                      Games  Gold  Silver  Bronze
# continent Country
# SA        Argentina     23    18      24      28
#           Brazil        21    23      30      55
#           Chile         22     2       7       4
#           Colombia      18     2       6      11
#           Cuba          19    72      67      70
# ...                    ...   ...     ...     ...
# AF        Togo           9     0       0       1
#           Tunisia       13     3       3       4
#           Uganda        14     2       3       2
#           Zambia        12     0       1       1
#           Zimbabwe      12     3       4       1
#
# [146 rows x 4 columns]

# %%
w_medals = medals.iloc[:,5:9]

# %%
w_medals.columns = ['Games','Gold','Silver','Bronze']

# %%
w_medals
# Out:
#                      Games  Gold  Silver  Bronze
# continent Country
# SA        Argentina     18     0       0       0
#           Brazil         7     0       0       0
#           Chile         16     0       0       0
#           Colombia       1     0       0       0
#           Cuba           0     0       0       0
# ...                    ...   ...     ...     ...
# AF        Togo           1     0       0       0
#           Tunisia        0     0       0       0
#           Uganda         0     0       0       0
#           Zambia         0     0       0       0
#           Zimbabwe       1     0       0       0
#
# [146 rows x 4 columns]

# %%
all_medals_wide =pd.concat([s_medals,w_medals],keys=['Summer','Winter'],axis=1)

# %%
all_medals_wide
# Out:
#                     Summer                    Winter
#                      Games Gold Silver Bronze  Games Gold Silver Bronze
# continent Country
# SA        Argentina     23   18     24     28     18    0      0      0
#           Brazil        21   23     30     55      7    0      0      0
#           Chile         22    2      7      4     16    0      0      0
#           Colombia      18    2      6     11      1    0      0      0
#           Cuba          19   72     67     70      0    0      0      0
# ...                    ...  ...    ...    ...    ...  ...    ...    ...
# AF        Togo           9    0      0      1      1    0      0      0
#           Tunisia       13    3      3      4      0    0      0      0
#           Uganda        14    2      3      2      0    0      0      0
#           Zambia        12    0      1      1      0    0      0      0
#           Zimbabwe      12    3      4      1      1    0      0      0
#
# [146 rows x 8 columns]

# %% [markdown]
# ## 12.

# %%
a12 = all_medals_wide.stack(0)

# %%
a12
# Out:
#                             Bronze  Games  Gold  Silver
# continent Country
# SA        Argentina Summer      28     23    18      24
#                     Winter       0     18     0       0
#           Brazil    Summer      55     21    23      30
#                     Winter       0      7     0       0
#           Chile     Summer       4     22     2       7
# ...                            ...    ...   ...     ...
# AF        Uganda    Winter       0      0     0       0
#           Zambia    Summer       1     12     0       1
#                     Winter       0      0     0       0
#           Zimbabwe  Summer       1     12     3       4
#                     Winter       0      1     0       0
#
# [292 rows x 4 columns]

# %% [markdown]
# ## 13.

# %%
a13 = all_medals_wide.stack()

# %%
a13
# Out:
#                             Summer  Winter
# continent Country
# SA        Argentina Games       23      18
#                     Gold        18       0
#                     Silver      24       0
#                     Bronze      28       0
#           Brazil    Games       21       7
# ...                            ...     ...
# AF        Zambia    Bronze       1       0
#           Zimbabwe  Games       12       1
#                     Gold         3       0
#                     Silver       4       0
#                     Bronze       1       0
#
# [584 rows x 2 columns]

# %%
a13.unstack(['continent', 'Country']).T
# Out:
#                             Games  Gold  Silver  Bronze
#        continent Country
# Summer SA        Argentina     23    18      24      28
#                  Brazil        21    23      30      55
#                  Chile         22     2       7       4
#                  Colombia      18     2       6      11
#                  Cuba          19    72      67      70
# ...                           ...   ...     ...     ...
# Winter AF        Togo           1     0       0       0
#                  Tunisia        0     0       0       0
#                  Uganda         0     0       0       0
#                  Zambia         0     0       0       0
#                  Zimbabwe       1     0       0       0
#
# [292 rows x 4 columns]

# %%
a13.unstack(['continent', 'Country']).T.reset_index()
# Out:
#     level_0 continent    Country  Games  Gold  Silver  Bronze
# 0    Summer        SA  Argentina     23    18      24      28
# 1    Summer        SA     Brazil     21    23      30      55
# 2    Summer        SA      Chile     22     2       7       4
# 3    Summer        SA   Colombia     18     2       6      11
# 4    Summer        SA       Cuba     19    72      67      70
# ..      ...       ...        ...    ...   ...     ...     ...
# 287  Winter        AF       Togo      1     0       0       0
# 288  Winter        AF    Tunisia      0     0       0       0
# 289  Winter        AF     Uganda      0     0       0       0
# 290  Winter        AF     Zambia      0     0       0       0
# 291  Winter        AF   Zimbabwe      1     0       0       0
#
# [292 rows x 7 columns]

# %%
b13 = a13.unstack(['continent', 'Country']).T.reset_index().melt(id_vars=['continent', 'Country', 'level_0', 'Games'])

# %%
b13.columns
# Out:
# Index(['continent', 'Country', 'level_0', 'Games', 'variable', 'value'], dtype='object')

# %%
b13.columns = ['continent', 'Country', 'Season', 'Games', 'Medal', 'Count']

# %%
b13.Country == 'Austria'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 871    False
# 872    False
# 873    False
# 874    False
# 875    False
# Name: Country, Length: 876, dtype: bool

# %%
b13.loc[b13.Country == 'Austria']
# Out:
#     continent  Country  Season  Games   Medal  Count
# 44         EU  Austria  Summer     26    Gold     18
# 190        EU  Austria  Winter     22    Gold     59
# 336        EU  Austria  Summer     26  Silver     33
# 482        EU  Austria  Winter     22  Silver     78
# 628        EU  Austria  Summer     26  Bronze     35
# 774        EU  Austria  Winter     22  Bronze     81

# %%
all_medals_long = b13

# %%
all_medals_long
# Out:
#     continent    Country  Season  Games   Medal  Count
# 0          SA  Argentina  Summer     23    Gold     18
# 1          SA     Brazil  Summer     21    Gold     23
# 2          SA      Chile  Summer     22    Gold      2
# 3          SA   Colombia  Summer     18    Gold      2
# 4          SA       Cuba  Summer     19    Gold     72
# ..        ...        ...     ...    ...     ...    ...
# 871        AF       Togo  Winter      1  Bronze      0
# 872        AF    Tunisia  Winter      0  Bronze      0
# 873        AF     Uganda  Winter      0  Bronze      0
# 874        AF     Zambia  Winter      0  Bronze      0
# 875        AF   Zimbabwe  Winter      1  Bronze      0
#
# [876 rows x 6 columns]

# %% [markdown]
# ## 14.

# %%
a14 = b13

# %%
a14.continent.describe()
# Out:
# count     876
# unique      7
# top        EU
# freq      282
# Name: continent, dtype: object

# %%
a14.continent.unique()
# Out:
# array(['SA', 'OT', 'OC', 'NA', 'EU', 'AS', 'AF'], dtype=object)

# %%
a14
# Out:
#     continent    Country  Season  Games   Medal  Count
# 0          SA  Argentina  Summer     23    Gold     18
# 1          SA     Brazil  Summer     21    Gold     23
# 2          SA      Chile  Summer     22    Gold      2
# 3          SA   Colombia  Summer     18    Gold      2
# 4          SA       Cuba  Summer     19    Gold     72
# ..        ...        ...     ...    ...     ...    ...
# 871        AF       Togo  Winter      1  Bronze      0
# 872        AF    Tunisia  Winter      0  Bronze      0
# 873        AF     Uganda  Winter      0  Bronze      0
# 874        AF     Zambia  Winter      0  Bronze      0
# 875        AF   Zimbabwe  Winter      1  Bronze      0
#
# [876 rows x 6 columns]

# %%
a14.groupby('continent').sum()
# Out:
#            Games  Count
# continent
# AF           972    347
# AS          1617   1710
# EU          3726  10956
# NA           375   3192
# OC           273    593
# OT           945    263
# SA           843    518

# %%
a14.Medal == 'Gold'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 871    False
# 872    False
# 873    False
# 874    False
# 875    False
# Name: Medal, Length: 876, dtype: bool

# %%
a14.Season == 'Summer'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 871    False
# 872    False
# 873    False
# 874    False
# 875    False
# Name: Season, Length: 876, dtype: bool

# %%
b14 = a14.loc[(a14.Medal == 'Gold') & (a14.Season == 'Summer')].groupby('continent').sum()

# %%
b14.sort_values('Count', ascending=False)
# Out:
#            Games  Count
# continent
# EU           677   2731
# NA            73   1048
# AS           383    531
# OC            57    184
# SA           224    141
# AF           294    103
# OT           246     71

# %%
a14.loc[(a14.Medal == 'Gold') & (a14.Season == 'Summer')].pivot_table(index='continent',columns='Medal',values='Count',aggfunc='sum').sort_values('Gold', ascending=False)
# Out:
# Medal      Gold
# continent
# EU         2731
# NA         1048
# AS          531
# OC          184
# SA          141
# AF          103
# OT           71

# %% [markdown]
# ## 15.

# %%
a15 = all_medals_wide

# %%
a15
# Out:
#                     Summer                    Winter
#                      Games Gold Silver Bronze  Games Gold Silver Bronze
# continent Country
# SA        Argentina     23   18     24     28     18    0      0      0
#           Brazil        21   23     30     55      7    0      0      0
#           Chile         22    2      7      4     16    0      0      0
#           Colombia      18    2      6     11      1    0      0      0
#           Cuba          19   72     67     70      0    0      0      0
# ...                    ...  ...    ...    ...    ...  ...    ...    ...
# AF        Togo           9    0      0      1      1    0      0      0
#           Tunisia       13    3      3      4      0    0      0      0
#           Uganda        14    2      3      2      0    0      0      0
#           Zambia        12    0      1      1      0    0      0      0
#           Zimbabwe      12    3      4      1      1    0      0      0
#
# [146 rows x 8 columns]

# %%
a15.groupby(['continent']).size()
# Out:
# continent
# AF    26
# AS    30
# EU    47
# NA     3
# OC     4
# OT    23
# SA    13
# dtype: int64

# %% [markdown]
# ## 16.

# %%
all_medals_wide.groupby(['continent']).sum()
# Out:
#           Summer                     Winter
#            Games  Gold Silver Bronze  Games Gold Silver Bronze
# continent
# AF           294   103    112    132     30    0      0      0
# AS           383   531    485    533    156   50     60     51
# EU           677  2731   2879   3139    565  735    728    744
# NA            73  1048    877    815     52  158    158    136
# OC            57   184    175    221     34    5      4      4
# OT           246    71     74     86     69   11      8     13
# SA           224   141    173    204     57    0      0      0

# %% [markdown]
# ## 17.

# %%
all_medals_long
# Out:
#     continent    Country  Season  Games   Medal  Count
# 0          SA  Argentina  Summer     23    Gold     18
# 1          SA     Brazil  Summer     21    Gold     23
# 2          SA      Chile  Summer     22    Gold      2
# 3          SA   Colombia  Summer     18    Gold      2
# 4          SA       Cuba  Summer     19    Gold     72
# ..        ...        ...     ...    ...     ...    ...
# 871        AF       Togo  Winter      1  Bronze      0
# 872        AF    Tunisia  Winter      0  Bronze      0
# 873        AF     Uganda  Winter      0  Bronze      0
# 874        AF     Zambia  Winter      0  Bronze      0
# 875        AF   Zimbabwe  Winter      1  Bronze      0
#
# [876 rows x 6 columns]

# %%
all_medals_long.groupby(['Season','Medal']).sum()
# Out:
#                Games  Count
# Season Medal
# Summer Bronze   1954   5130
#        Gold     1954   4809
#        Silver   1954   4775
# Winter Bronze    963    948
#        Gold      963    959
#        Silver    963    958

# %% [markdown]
# ## 18.

# %%
all_medals_wide
# Out:
#                     Summer                    Winter
#                      Games Gold Silver Bronze  Games Gold Silver Bronze
# continent Country
# SA        Argentina     23   18     24     28     18    0      0      0
#           Brazil        21   23     30     55      7    0      0      0
#           Chile         22    2      7      4     16    0      0      0
#           Colombia      18    2      6     11      1    0      0      0
#           Cuba          19   72     67     70      0    0      0      0
# ...                    ...  ...    ...    ...    ...  ...    ...    ...
# AF        Togo           9    0      0      1      1    0      0      0
#           Tunisia       13    3      3      4      0    0      0      0
#           Uganda        14    2      3      2      0    0      0      0
#           Zambia        12    0      1      1      0    0      0      0
#           Zimbabwe      12    3      4      1      1    0      0      0
#
# [146 rows x 8 columns]

# %%
all_medals_wide.loc[all_medals_wide.Summer.Games>0].iloc[:,1:2].groupby('continent').mean()
# Out:
#                Summer
#                  Gold
# continent
# AF           3.961538
# AS          17.700000
# EU          58.106383
# NA         349.333333
# OC          46.000000
# OT           3.086957
# SA          10.846154

# %% [markdown]
# ## 19.

# %%
all_medals_wide.columns
# Out:
# MultiIndex([('Summer',  'Games'),
#             ('Summer',   'Gold'),
#             ('Summer', 'Silver'),
#             ('Summer', 'Bronze'),
#             ('Winter',  'Games'),
#             ('Winter',   'Gold'),
#             ('Winter', 'Silver'),
#             ('Winter', 'Bronze')],
#            )

# %%
s19 = all_medals_wide.loc[all_medals_wide.Summer.Games>0].iloc[:,0:1].groupby('continent').count()

# %%
s19
# Out:
#           Summer
#            Games
# continent
# AF            26
# AS            30
# EU            47
# NA             3
# OC             4
# OT            23
# SA            13

# %%
w19 = all_medals_wide.loc[all_medals_wide.Winter.Games>0].iloc[:,4:5].groupby('continent').count()

# %%
w19
# Out:
#           Winter
#            Games
# continent
# AF            11
# AS            17
# EU            46
# NA             3
# OC             3
# OT            12
# SA             9

# %%
pd.concat([s19,w19],axis=1)
# Out:
#           Summer Winter
#            Games  Games
# continent
# AF            26     11
# AS            30     17
# EU            47     46
# NA             3      3
# OC             4      3
# OT            23     12
# SA            13      9

# %% [markdown]
# ## 20.

# %%
all_medals_wide.loc[all_medals_wide.Summer.Games>0].iloc[:,[1]].groupby('continent').mean()
# Out:
#                Summer
#                  Gold
# continent
# AF           3.961538
# AS          17.700000
# EU          58.106383
# NA         349.333333
# OC          46.000000
# OT           3.086957
# SA          10.846154

# %%
all_medals_wide.loc[all_medals_wide.Winter.Games>0].iloc[:,[5]].groupby('continent').mean()
# Out:
#               Winter
#                 Gold
# continent
# AF          0.000000
# AS          2.941176
# EU         15.978261
# NA         52.666667
# OC          1.666667
# OT          0.916667
# SA          0.000000

# %%
all_medals_wide.loc[(all_medals_wide.Summer.Games>0) | (all_medals_wide.Winter.Games>0)].groupby('continent').mean().iloc[:,[1, 5]]
# Out:
#                Summer     Winter
#                  Gold       Gold
# continent
# AF           3.961538   0.000000
# AS          17.700000   1.666667
# EU          58.106383  15.638298
# NA         349.333333  52.666667
# OC          46.000000   1.250000
# OT           3.086957   0.478261
# SA          10.846154   0.000000
